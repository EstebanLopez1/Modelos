# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import numpy as np
import seaborn as sns
plt.style.use("classic")

df = pd.read_csv (r'C:\Users\esteb\OneDrive\Escritorio\Maestría Analytics\Vacacional\Oil.csv', skiprows=2)
columnas=["Mes", "Oil"]
df.columns=columnas
df["Mes"] = pd.to_datetime(df['Mes'])
df.set_index('Mes', inplace=True)
df.head()
# Out:
#             Oil
# Mes
# 2004-01-01   84
# 2004-02-01   56
# 2004-03-01   48
# 2004-04-01   81
# 2004-05-01   42

# %%
df.plot(figsize=(8, 5), grid=True, linewidth=3, fontsize=15, title="Serie de Timepo Petróleo")
plt.ylabel("Interés de Búsqueda")
plt.axhline(df["Oil"].mean(), color ="red", linestyle="dashed", label="Promedio")
plt.legend()
plt.show()

# %%
result = adfuller(df["Oil"])
result[1]
# Out:
# 0.011250934586182535

# %%
media_movil=df["Oil"].rolling(12).mean()
media_movil.plot(figsize=(8,5), linewidth=3, fontsize=15)
plt.ylabel("Media Movil Interés de Búsqueda")
plt.show()

# %%
df_dif=df["Oil"].diff()
df_dif.plot(figsize=(8,5), linewidth=2, fontsize=15)
plt.xlabel('Year', fontsize=20);

# %%
result = adfuller(df_dif.dropna())
result[1]
# Out:
# 1.0306392153446224e-05

# %%
plt.figure(figsize=(8,5))
pd.plotting.autocorrelation_plot(df,linewidth=3, color='brown')
plt.title('Autocorrelacion - Oil')
plt.xlabel('Rezago (lag) en meses')
plt.xticks(np.arange(1,12), rotation=90, fontsize=6);
